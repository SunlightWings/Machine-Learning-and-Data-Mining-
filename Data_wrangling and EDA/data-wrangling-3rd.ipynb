# %% [markdown]
# # 1. Opening the file

# %%
import numpy as np
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/sdot-collision/SDOT_Collisions_All_Years_-681745443618578502.csv

# %%
# Load the dataset into a DataFrame
df = pd.read_csv('/kaggle/input/sdot-collision/SDOT_Collisions_All_Years_-681745443618578502.csv', low_memory = False)

# %% [markdown]
# # 2. Basic Operations

# %%
df.head()
# Out:
#    OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO   STATUS  \
# 0   7694037    System.Byte[]    1084       1084  3605933  Matched
# 1   7694038    System.Byte[]    1344       1344  3605911  Matched
# 2   7694039    System.Byte[]    1145       1145  3581513  Matched
# 3   7694040    System.Byte[]  349437     350917  EC25293  Matched
# 4   7694041    System.Byte[]   43700      43700  2064240  Matched
#
#        ADDRTYPE   INTKEY                                      LOCATION  \
# 0         Block      NaN   23RD AVE BETWEEN E SPRING ST AND E UNION ST
# 1         Block      NaN    E MADISON ST BETWEEN 13TH AVE AND 14TH AVE
# 2         Block      NaN  DEXTER AVE N BETWEEN WARD ST AND PROSPECT ST
# 3  Intersection  32431.0                RAINIER AVE S AND S ESTELLE ST
# 4         Block      NaN    E YESLER WAY BETWEEN 14TH AVE AND 15TH AVE
#
#   EXCEPTRSNCODE  ... HITPARKEDCAR    SPDCASENO Source of the collision report  \
# ...

# %%
df.head(3)     # first 3 instances only
# Out:
#    OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO   STATUS ADDRTYPE  \
# 0   7694037    System.Byte[]    1084       1084  3605933  Matched    Block
# 1   7694038    System.Byte[]    1344       1344  3605911  Matched    Block
# 2   7694039    System.Byte[]    1145       1145  3581513  Matched    Block
#
#    INTKEY                                      LOCATION EXCEPTRSNCODE  ...  \
# 0     NaN   23RD AVE BETWEEN E SPRING ST AND E UNION ST           NaN  ...
# 1     NaN    E MADISON ST BETWEEN 13TH AVE AND 14TH AVE           NaN  ...
# 2     NaN  DEXTER AVE N BETWEEN WARD ST AND PROSPECT ST           NaN  ...
#
#   HITPARKEDCAR    SPDCASENO Source of the collision report  \
# 0            N    13-100391                           PTCR
# 1            N    13-103024                           PTCR
# 2            N  2013-102008                           PTCR
#
#                 Source description  Added by User            Added date  \
# ...

# %%
df.tail()         #last 5 instances
# Out:
#         OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO     STATUS  \
# 248391   7942428    System.Byte[]  355423     356883  EC56862    Matched
# 248392   7942429    System.Byte[]  357180     358640  EC68498    Matched
# 248393   7942430    System.Byte[]  356531     357991  3902279    Matched
# 248394   7942431    System.Byte[]  355922     357382  EC59712    Matched
# 248395   7942432    System.Byte[]  356686     358146  ED06759  Unmatched
#
#        ADDRTYPE  INTKEY                                           LOCATION  \
# 248391    Block     NaN  WEST MARGINAL WAY S BETWEEN 1ST AVE S AND S HO...
# 248392    Block     NaN  N NORTHGATE WAY BETWEEN MERIDIAN AVE N AND COR...
# 248393    Block     NaN         23RD AVE BETWEEN E YESLER WAY AND E FIR ST
# 248394    Block     NaN      8TH AVE W BETWEEN W RAYE ST AND W BOTHWELL ST
# 248395    Block     NaN           7TH AVE BETWEEN OLIVE WAY AND STEWART ST
#
#        EXCEPTRSNCODE  ... HITPARKEDCAR    SPDCASENO  \
# ...

# %%
df.tail(1)            # the very last instance only
# Out:
#         OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO     STATUS  \
# 248395   7942432    System.Byte[]  356686     358146  ED06759  Unmatched
#
#        ADDRTYPE  INTKEY                                  LOCATION  \
# 248395    Block     NaN  7TH AVE BETWEEN OLIVE WAY AND STEWART ST
#
#        EXCEPTRSNCODE  ... HITPARKEDCAR SPDCASENO  \
# 248395           NaN  ...            N       NaN
#
#        Source of the collision report                Source description  \
# 248395                           CVCR  Citizen Vehicle Collision Report
#
#         Added by User             Added date  Modified by  \
# 248395        BRUKTAH  12/7/2022 12:00:00 AM      BRUKTAH
#
#                 Modified date             x              y
# 248395  12/7/2022 12:00:00 AM  1.269891e+06  227564.010013
#
# [1 rows x 50 columns]

# %%
df.columns                  # returns the column labels of the DataFrame.
# Out:
# Index(['OBJECTID', 'SE_ANNO_CAD_DATA', 'INCKEY', 'COLDETKEY', 'REPORTNO',
#        'STATUS', 'ADDRTYPE', 'INTKEY', 'LOCATION', 'EXCEPTRSNCODE',
#        'EXCEPTRSNDESC', 'SEVERITYCODE', 'SEVERITYDESC', 'COLLISIONTYPE',
#        'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INJURIES',
#        'SERIOUSINJURIES', 'FATALITIES', 'INCDATE', 'INCDTTM', 'JUNCTIONTYPE',
#        'SDOT_COLCODE', 'SDOT_COLDESC', 'INATTENTIONIND', 'UNDERINFL',
#        'WEATHER', 'ROADCOND', 'LIGHTCOND', 'DIAGRAMLINK', 'REPORTLINK',
#        'PEDROWNOTGRNT', 'SDOTCOLNUM', 'SPEEDING', 'STCOLCODE', 'ST_COLDESC',
#        'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR', 'SPDCASENO',
#        'Source of the collision report', 'Source description', 'Added by User',
#        'Added date', 'Modified by', 'Modified date', 'x', 'y'],
#       dtype='object')

# %%
df.info()             # dataframe summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248396 entries, 0 to 248395
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   OBJECTID                        248396 non-null  int64
#  1   SE_ANNO_CAD_DATA                248396 non-null  object
#  2   INCKEY                          248396 non-null  int64
#  3   COLDETKEY                       248396 non-null  int64
#  4   REPORTNO                        248396 non-null  object
#  5   STATUS                          248396 non-null  object
#  6   ADDRTYPE                        244460 non-null  object
#  7   INTKEY                          82857 non-null   float64
#  8   LOCATION                        243520 non-null  object
#  9   EXCEPTRSNCODE                   12800 non-null   object
#  10  EXCEPTRSNDESC                   12800 non-null   object
#  11  SEVERITYCODE                    248395 non-null  object
# ...

# %%
df.describe()                # description of each column
# Out:
#            OBJECTID         INCKEY      COLDETKEY         INTKEY  \
# count  2.483960e+05  248396.000000  248396.000000   82857.000000
# mean   7.818234e+06  167244.452990  167609.169624   38206.675296
# std    7.170589e+04  106096.127717  106614.192538   54470.226629
# min    7.694037e+06    1001.000000    1001.000000   23807.000000
# 25%    7.756136e+06   78387.750000   78387.750000   28667.000000
# 50%    7.818234e+06  140879.500000  140879.500000   30102.000000
# 75%    7.880333e+06  244952.250000  245552.250000   34082.000000
# max    7.942432e+06  371349.000000  372829.000000  858453.000000
#
#          PERSONCOUNT       PEDCOUNT    PEDCYLCOUNT       VEHCOUNT  \
# count  248396.000000  248396.000000  248396.000000  248396.000000
# mean        2.237371       0.038982       0.027810       1.697201
# std         1.442160       0.203924       0.165892       0.861049
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # 3. Basic Query Operations

# %%
# to select the first row
first = df.iloc[0]
first
# Out:
# OBJECTID                                                                    7694037
# SE_ANNO_CAD_DATA                                                      System.Byte[]
# INCKEY                                                                         1084
# COLDETKEY                                                                      1084
# REPORTNO                                                                    3605933
# STATUS                                                                      Matched
# ADDRTYPE                                                                      Block
# INTKEY                                                                          NaN
# LOCATION                                23RD AVE BETWEEN E SPRING ST AND E UNION ST
# EXCEPTRSNCODE                                                                   NaN
# EXCEPTRSNDESC                                                                   NaN
# ...

# %%
# to selct the rows from index 1 to 4
multiple = df.iloc[1:5]        # the interval is "[)" i.e closed and open
multiple
# Out:
#    OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO   STATUS  \
# 1   7694038    System.Byte[]    1344       1344  3605911  Matched
# 2   7694039    System.Byte[]    1145       1145  3581513  Matched
# 3   7694040    System.Byte[]  349437     350917  EC25293  Matched
# 4   7694041    System.Byte[]   43700      43700  2064240  Matched
#
#        ADDRTYPE   INTKEY                                      LOCATION  \
# 1         Block      NaN    E MADISON ST BETWEEN 13TH AVE AND 14TH AVE
# 2         Block      NaN  DEXTER AVE N BETWEEN WARD ST AND PROSPECT ST
# 3  Intersection  32431.0                RAINIER AVE S AND S ESTELLE ST
# 4         Block      NaN    E YESLER WAY BETWEEN 14TH AVE AND 15TH AVE
#
#   EXCEPTRSNCODE  ... HITPARKEDCAR    SPDCASENO Source of the collision report  \
# 1           NaN  ...            N    13-103024                           PTCR
# 2           NaN  ...            N  2013-102008                           PTCR
# ...

# %%
# to select first column
col = df.iloc[:,0]
col
# Out:
# 0         7694037
# 1         7694038
# 2         7694039
# 3         7694040
# 4         7694041
#            ...
# 248391    7942428
# 248392    7942429
# 248393    7942430
# 248394    7942431
# 248395    7942432
# Name: OBJECTID, Length: 248396, dtype: int64

# %%
# to select the 2nd and 3rd columns  (and all rows)
columns = df.iloc[:, [1, 2]]
columns
# Out:
#        SE_ANNO_CAD_DATA  INCKEY
# 0         System.Byte[]    1084
# 1         System.Byte[]    1344
# 2         System.Byte[]    1145
# 3         System.Byte[]  349437
# 4         System.Byte[]   43700
# ...                 ...     ...
# 248391    System.Byte[]  355423
# 248392    System.Byte[]  357180
# 248393    System.Byte[]  356531
# 248394    System.Byte[]  355922
# 248395    System.Byte[]  356686
#
# [248396 rows x 2 columns]

# %%
# to select 2nd row, and 2nd and 3rd columns (combination of rows and columns)
combination = df.iloc[1, [1, 2]]
combination
# Out:
# SE_ANNO_CAD_DATA    System.Byte[]
# INCKEY                       1344
# Name: 1, dtype: object

# %% [markdown]
# # 4. Logical Operators

# %%
# selects rows where the value in the 'ADDRTYPE' column is equal to 'Intersection'.
condition1 = df.loc[df['ADDRTYPE'] == 'Intersection']
condition1
# Out:
#         OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO     STATUS  \
# 3        7694040    System.Byte[]  349437     350917  EC25293    Matched
# 8        7694045    System.Byte[]  369095     370575  EE37804  Unmatched
# 11       7694048    System.Byte[]    1312       1312  3476309    Matched
# 15       7694052    System.Byte[]  355241     356701  3890903    Matched
# 16       7694053    System.Byte[]    1349       1349  3282608    Matched
# ...          ...              ...     ...        ...      ...        ...
# 248385   7942422    System.Byte[]  355745     357205  EC94648    Matched
# 248386   7942423    System.Byte[]  355419     356879  EC91672  Unmatched
# 248388   7942425    System.Byte[]  356230     357690  3916466    Matched
# 248389   7942426    System.Byte[]  355750     357210  EC94652    Matched
# 248390   7942427    System.Byte[]  356225     357685  EC62308    Matched
#
#             ADDRTYPE    INTKEY                                  LOCATION  \
# ...

# %%
# selects rows where the value in the 'WEATHER' column is equal to 'Clear' AND the value in the 'ROADCOND' column is equal to 'Dry'.
condition2 = df.loc[(df['WEATHER'] == 'Clear') & (df['ROADCOND'] == 'Dry')]
condition2
# Out:
#         OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO   STATUS  \
# 0        7694037    System.Byte[]    1084       1084  3605933  Matched
# 1        7694038    System.Byte[]    1344       1344  3605911  Matched
# 2        7694039    System.Byte[]    1145       1145  3581513  Matched
# 4        7694041    System.Byte[]   43700      43700  2064240  Matched
# 6        7694043    System.Byte[]  355142     356602  EC88419  Matched
# ...          ...              ...     ...        ...      ...      ...
# 248388   7942425    System.Byte[]  356230     357690  3916466  Matched
# 248389   7942426    System.Byte[]  355750     357210  EC94652  Matched
# 248391   7942428    System.Byte[]  355423     356883  EC56862  Matched
# 248392   7942429    System.Byte[]  357180     358640  EC68498  Matched
# 248393   7942430    System.Byte[]  356531     357991  3902279  Matched
#
#             ADDRTYPE   INTKEY  \
# 0              Block      NaN
# 1              Block      NaN
# ...

# %%
condition3 = df.loc[(df['WEATHER'] == 'Clear') | (df['WEATHER'] == 'Partly Cloudy')]
condition3
# Out:
#         OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO   STATUS  \
# 0        7694037    System.Byte[]    1084       1084  3605933  Matched
# 1        7694038    System.Byte[]    1344       1344  3605911  Matched
# 2        7694039    System.Byte[]    1145       1145  3581513  Matched
# 4        7694041    System.Byte[]   43700      43700  2064240  Matched
# 6        7694043    System.Byte[]  355142     356602  EC88419  Matched
# ...          ...              ...     ...        ...      ...      ...
# 248388   7942425    System.Byte[]  356230     357690  3916466  Matched
# 248389   7942426    System.Byte[]  355750     357210  EC94652  Matched
# 248391   7942428    System.Byte[]  355423     356883  EC56862  Matched
# 248392   7942429    System.Byte[]  357180     358640  EC68498  Matched
# 248393   7942430    System.Byte[]  356531     357991  3902279  Matched
#
#             ADDRTYPE   INTKEY  \
# 0              Block      NaN
# 1              Block      NaN
# ...

# %%
condition4 = df.loc[((df['WEATHER'] == 'Clear') | (df['WEATHER'] == 'Partly Cloudy')) & (df['ROADCOND'] == 'Dry')]
condition4
# Out:
#         OBJECTID SE_ANNO_CAD_DATA  INCKEY  COLDETKEY REPORTNO   STATUS  \
# 0        7694037    System.Byte[]    1084       1084  3605933  Matched
# 1        7694038    System.Byte[]    1344       1344  3605911  Matched
# 2        7694039    System.Byte[]    1145       1145  3581513  Matched
# 4        7694041    System.Byte[]   43700      43700  2064240  Matched
# 6        7694043    System.Byte[]  355142     356602  EC88419  Matched
# ...          ...              ...     ...        ...      ...      ...
# 248388   7942425    System.Byte[]  356230     357690  3916466  Matched
# 248389   7942426    System.Byte[]  355750     357210  EC94652  Matched
# 248391   7942428    System.Byte[]  355423     356883  EC56862  Matched
# 248392   7942429    System.Byte[]  357180     358640  EC68498  Matched
# 248393   7942430    System.Byte[]  356531     357991  3902279  Matched
#
#             ADDRTYPE   INTKEY  \
# 0              Block      NaN
# 1              Block      NaN
# ...

# %% [markdown]
# # 5. Univariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# lets create a function for a simpler design 
def plot_numerical_features(df, numerical_features):
    for feature in numerical_features:
        # Histogram
        plt.figure(figsize=(8, 5))
        sns.histplot(df[feature], kde=True, color='skyblue')
        plt.title(f'Histogram of {feature}')
        plt.xlabel(feature)
        plt.ylabel('Frequency')
        plt.show()

        # Box plot
        plt.figure(figsize=(8, 5))
        sns.boxplot(data=df, y=feature, color='lightgreen')
        plt.title(f'Box plot of {feature}')
        plt.ylabel(feature)
        plt.show()

        # KDE plot
        plt.figure(figsize=(8, 5))
        sns.kdeplot(df[feature], shade=True, color='salmon')
        plt.title(f'Kernel Density Estimate plot of {feature}')
        plt.xlabel(feature)
        plt.ylabel('Density')
        plt.show()

# %%
numerical_features = ['PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INJURIES', 'SERIOUSINJURIES', 'FATALITIES']

# %%
plot_numerical_features(df, numerical_features)   #function call to plot
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /tmp/ipykernel_67/725613328.py:21: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[feature], shade=True, color='salmon')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
# lets create similar function for categorical
def plot_categorical_features(df, categorical_features):
    for feature in categorical_features:
        # Bar plot
        plt.figure(figsize=(8, 5))
        sns.countplot(data=df, x=feature, palette='pastel')
        plt.title(f'Bar plot of {feature}')
        plt.xlabel(feature)
        plt.ylabel('Count')
        plt.xticks(rotation=45)
        plt.show()

        # Pie chart
        plt.figure(figsize=(8, 5))
        value_counts = df[feature].value_counts()
        value_counts.plot(kind='pie', autopct='%1.1f%%', colors=sns.color_palette('pastel'), startangle=140)
        plt.title(f'Pie chart of {feature}')
        plt.ylabel('')
        plt.show()

# %%
categorical_features = ['ADDRTYPE', 'COLLISIONTYPE', 'WEATHER', 'ROADCOND', 'LIGHTCOND']

# %%
plot_categorical_features(df, categorical_features)    #function call

# %% [markdown]
# # 6. Bivariate and Multivariate Analysis

# %%
def plot_bivariate_analysis(df):
    # Bivariate analysis with target column (severity description)
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x='SEVERITYDESC', hue='ADDRTYPE', palette='pastel')
    plt.title('Count of Accidents by Address Type and Severity Description')
    plt.xlabel('Severity Description')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.legend(title='Address Type')
    plt.show()

# %%
plot_bivariate_analysis(df)

# %%
def plot_multivariate_analysis(df):
    # Multivariate analysis with target column (severity description)
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x='PERSONCOUNT', y='VEHCOUNT', hue='SEVERITYDESC', palette='viridis', alpha=0.7)
    plt.title('Scatter plot of Person Count vs Vehicle Count by Severity Description')
    plt.xlabel('Person Count')
    plt.ylabel('Vehicle Count')
    plt.legend(title='Severity Description')
    plt.show()

# %%
plot_multivariate_analysis(df)

# %% [markdown]
# # 7 . Various Hypothesis Tests

# %% [markdown]
# a) The Chi-Square test is typically used for categorical data. Let's assume we are interested in testing if there is a significant relationship between ADDRTYPE and SEVERITYDESC.

# %%
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table = pd.crosstab(df['ADDRTYPE'], df['SEVERITYDESC'])

# Perform the Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f'Chi-Square Statistic: {chi2}')
print(f'p-value: {p}')
# Out:
# Chi-Square Statistic: 10296.33166473314
# p-value: 0.0

# %% [markdown]
# b) The Shapiro-Wilk test tests the null hypothesis that the data was drawn from a normal distribution.

# %%
from scipy.stats import shapiro

# Test for normality on a numerical feature
stat, p = shapiro(df['PERSONCOUNT'].dropna())
print('Statistics=%.3f, p=%.3f' % (stat, p))

# Interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.725, p=0.000
# Sample does not look Gaussian (reject H0)
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# c) The Kolmogorov-Smirnov test compares the sample distribution with a reference probability distribution ( such as normal distribution).

# %%
from scipy.stats import kstest

# Test for normality on a numerical feature
stat, p = kstest(df['PERSONCOUNT'].dropna(), 'norm')
print('Statistics=%.3f, p=%.3f' % (stat, p))

# Interpret
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.806, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
df2 = df.dropna(subset=numerical_features + ['SEVERITYCODE'], inplace=True)

# %% [markdown]
# # 8 and 9. Correlation Testing and Summary

# %%
from scipy.stats import pearsonr

# List of numerical features
numerical_features = ['PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INJURIES', 'SERIOUSINJURIES', 'FATALITIES']

# Calculate Pearson correlation for each pair of features
for i in range(len(numerical_features)):
    for j in range(i+1, len(numerical_features)):
        feature1 = numerical_features[i]
        feature2 = numerical_features[j]
        correlation_coefficient, p_value = pearsonr(df[feature1].dropna(), df[feature2].dropna())
        print(f"Pearson Correlation Coefficient between {feature1} and {feature2}: {correlation_coefficient:.4f}, p-value: {p_value:.4f}")

# Visualize relationships using scatterplots for relationships
for feature1 in numerical_features:
    for feature2 in numerical_features:
        if feature1 != feature2:
            plt.figure(figsize=(6, 4))
            sns.scatterplot(x=df[feature1], y=df[feature2])
            plt.title(f'Scatter plot between {feature1} and {feature2}')
            plt.xlabel(feature1)
            plt.ylabel(feature2)
            plt.show()
# Out:
# Pearson Correlation Coefficient between PERSONCOUNT and PEDCOUNT: 0.0119, p-value: 0.0000
# Pearson Correlation Coefficient between PERSONCOUNT and PEDCYLCOUNT: -0.0090, p-value: 0.0000
# Pearson Correlation Coefficient between PERSONCOUNT and VEHCOUNT: 0.5672, p-value: 0.0000
# Pearson Correlation Coefficient between PERSONCOUNT and INJURIES: 0.3234, p-value: 0.0000
# Pearson Correlation Coefficient between PERSONCOUNT and SERIOUSINJURIES: 0.1019, p-value: 0.0000
# Pearson Correlation Coefficient between PERSONCOUNT and FATALITIES: 0.0409, p-value: 0.0000
# Pearson Correlation Coefficient between PEDCOUNT and PEDCYLCOUNT: -0.0179, p-value: 0.0000
# Pearson Correlation Coefficient between PEDCOUNT and VEHCOUNT: -0.1422, p-value: 0.0000
# Pearson Correlation Coefficient between PEDCOUNT and INJURIES: 0.1689, p-value: 0.0000
# Pearson Correlation Coefficient between PEDCOUNT and SERIOUSINJURIES: 0.1450, p-value: 0.0000
# ...

# %%
# Create an empty correlation matrix DataFrame
correlation_matrix = pd.DataFrame(index=numerical_features, columns=numerical_features)

# Calculate Pearson correlation coefficient for each pair of numerical features
for feature1 in numerical_features:
    for feature2 in numerical_features:
        correlation_coefficient, _ = pearsonr(df[feature1], df[feature2])  # Using pearsonr function
        correlation_matrix.loc[feature1, feature2] = correlation_coefficient

# Convert correlation coefficients to numeric values
correlation_matrix = correlation_matrix.astype(float)

# Create a heatmap using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='RdYlBu', fmt=".2f")  # Change the colormap to 'RdYlBu'
plt.title('Correlation Matrix of Numerical Features')
plt.show()
